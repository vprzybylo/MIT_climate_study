# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import sys
sys.path.append("..") # Adds higher directory to python modules path.
from MIT_study import extreme

# %%
filename = '/home/vanessa/hulk/MIT_study/data/mesonet_wind_2015_2022.parquet.gzip'
df = pd.read_parquet(filename)

# %%
df['wspd_merge'].hist(by=df['station'], figsize=(25,25), range=[0, 15]);

# %%
extreme.main()
# Out:
# done reading in the data
# done converting to mph
# /home/vanessa/hulk/MIT_study/src/notebooks/../MIT_study/extreme.py:141: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   magnitude_dict = p.map(func, [group for name, group in dfGrouped])
# dictionary saved successfully to file
